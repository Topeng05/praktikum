# %% [markdown]
# <a href="https://colab.research.google.com/github/Topeng05/praktikum/blob/main/Modul3_220411100086_SeleksiDanIterasi2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1 Flowchart dan Implementasi

# %% [markdown]
# #1.1 Bilangan Pembagi
# Buatlah flowchart (tidak harus menggunakan flogorithm) untuk menampilkan bilangan-bilangan pembagi
# yang sama (antara dua buah bilangan, yang merupakan inputan dari user), dan dari bilangan pembagi
# tersebut, tampilkan bilangan pembagi terbesar. Implementasikan flowchart yang sudah dibuat (bukan
# generate dari flowgorithm) dengan menggunakan bahasa Python, sehingga menghasilkan output seperti
# contoh-contoh yang terdapat pada Gambar 1.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Bil1=int(input('Masukkan bilangan pertama = '))
Bil2=int(input('Masukkan bilangan kedua = '))
count=1
for i in range (1,Bil2+1):
    if Bil1%i==0 and Bil2%i==0:
        x=i
        print('Pembagi yang sama -',count,'=',i)
        count=count+1
print('Pembagi yang sama terbesar adalah',x)
# Out:
# Masukkan bilangan pertama = 8
# Masukkan bilangan kedua = 20
# Pembagi yang sama - 1 = 1
# Pembagi yang sama - 2 = 2
# Pembagi yang sama - 3 = 4
# Pembagi yang sama terbesar adalah 4

# %% [markdown]
# #1.2 Pemecahan bilangan
# Buat flowchart dan implementasikan flowchart tersebut (bukan generate code dari flowchart) untuk membagi
# bilangan menjadi bagian ratusan ribu, puluhan ribu, ribuan,ratusan, puluhan, dan satuan. Dimana bilangan
# yang akan dibagi adalah inputan dari user. Contoh output dapat dilihat pada Gambar 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
IDR=int(input('Masukkan angka = '))
uang=100000
count=1
while IDR>0:
    print(count,':',int(IDR//uang),'x',int(uang))
    IDR=IDR%uang
    uang=uang//10
    count=count+1
# Out:
# Masukkan angka = 79542
# 1 : 0 x 100000
# 2 : 7 x 10000
# 3 : 9 x 1000
# 4 : 5 x 100
# 5 : 4 x 10
# 6 : 2 x 1
